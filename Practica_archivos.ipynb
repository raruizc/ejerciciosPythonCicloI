# %% [markdown]
# # Reto Semana 4

# %%
with open('C:/Users/Ricardo/Desktop/MisionTIC/Modulo 1/Ejercicios/archivos/MinTIC2022-master/files/data.txt', 'r') as f:
    data = f.read()
    print(data)
# Out:
# Hola amigos!!!

# %%
import json 
import requests
import math
from pprint import pprint

def tirilla():
    return"Centro Comercial Unaleño\n" +"Compra más y Gasta Menos\n"+ "NIT: 899.999.063\n" + "Cliente: " + cedula + "\nArt Cant Precio"
def Descuento(subtotal):
    if subtotal > 150000 and subtotal <= 300000:
        descuento = math.ceil(subtotal * 0.10)
        total = math.ceil(subtotal - descuento)
    elif subtotal > 300000 and subtotal <= 700000:
        descuento = subtotal * 0.15
        total = math.ceil(subtotal - descuento)        
    elif subtotal > 700000:
        descuento = subtotal * 0.2
        total = math.ceil(subtotal - descuento)
    else:
        descuento = 0
        total = math.ceil(subtotal - descuento)         
    return "Total: $"+ str(total) +"\nEn esta compra tu descuento fue $"+str(int(descuento)) +"\nGracias por tu compra"
    
url = input("Digite la URL: ")
#https://raw.githubusercontent.com/arleserp/MinTIC2022/master/json/comprassmall.json
response = requests.get(url)
datos = json.loads(response.text)


clientes = []
productos = []
subtotal = 0
for i in range(len(datos)):
  if "productos" in datos[i]:
    productos.append(datos[i]["productos"])
  if "cliente" in datos[i]:
    clientes.append(datos[i]["cliente"])

for i in range(len(clientes)):
  cedula = clientes[i]
  print(tirilla())
  for elementos in productos[i]:
    nombre = elementos["nombre"]
    cantidad = elementos["cantidad"]
    precio = elementos["cantidad"]* elementos["precio unitario"]
    print(nombre + " x"+str(cantidad)+ " $"+str(precio))
    subtotal += precio
  print(Descuento(subtotal))
  subtotal = 0
  print("---")
# Out:
# Centro Comercial Unaleño
# Compra más y Gasta Menos
# NIT: 899.999.063
# Cliente: 80849599
# Art Cant Precio
# Chocolatinas Cohete x3 $900
# Mora x1 $1000
# Pan de Maiz x5 $1500
# Total: $3400
# En esta compra tu descuento fue $0
# Gracias por tu compra
# ---
# Centro Comercial Unaleño
# Compra más y Gasta Menos
# NIT: 899.999.063
# Cliente: 1022734737
# Art Cant Precio
# Televisor x2 $3000000
# Teatro en Casa x1 $450000
# Total: $2760000
# En esta compra tu descuento fue $690000
# Gracias por tu compra
# ---

# %% [markdown]
# # Ejercicios de Archivos

# %%
#Archivo JSON con url función requests
import json
import requests
from pprint import pprint

response = requests.get("https://jsonplaceholder.typicode.com/todos")
pendientes = json.loads(response.text)

pprint(pendientes)
# Out:
# dolores architecto voluptatum',
#   'userId': 1},
#  {'completed': True,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'userId': 1},
#  {'completed': True,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'userId': 1},
#  {'completed': True,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'userId': 1},
#  {'completed': False,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'userId': 1},
#  {'completed': True,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'userId': 1},
#  {'completed': True,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'userId': 1},
#  {'completed': False,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'userId': 2},
#  {'completed': True,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'userId': 2},
#  {'completed': False,
# ...

# %% [markdown]
# # Serialización

# %%
import json
from pprint import pprint

x = {
    "Nombre": "Douglas",
    "Apellido": "Crockford",
    "hobbies": ["trotar", "bucear", "cantar"],
    "age": 64,
    "hijos": [
        {
            "Nombre": "Alice",
            "age": 16
        },
        {
            "Nombre": "Bob",
            "age": 8
        }
    ]
}

with open("C:/Users/Ricardo/Desktop/MisionTIC/Modulo 1/Ejercicios/archivos/MinTIC2022-master/json/data_file", "w") as write_file:
    json.dump(x, write_file)

json_string = json.dumps(x)
print(json_string, type(json_string))

with open("C:/Users/Ricardo/Desktop/MisionTIC/Modulo 1/Ejercicios/archivos/MinTIC2022-master/json/data_file.json", "r") as read_file:
    data = json.load(read_file)

pprint(data)
print(type(data))
# Out:
# {"Nombre": "Douglas", "Apellido": "Crockford", "hobbies": ["trotar", "bucear", "cantar"], "age": 64, "hijos": [{"Nombre": "Alice", "age": 16}, {"Nombre": "Bob", "age": 8}]} <class 'str'>
# {'presidente': {'edad': 44, 'nombre': 'Ivan Duque'}}
# <class 'dict'>

# %% [markdown]
# # Ejercicio Archivo JSON

# %%
import json
from pprint import pprint

with open("C:/Users/Ricardo/Desktop/MisionTIC/Modulo 1/Ejercicios/archivos/MinTIC2022-master/json/compras.json", "r") as archivo_json:
    compras = json.load(archivo_json)

pprint(compras)
print(type(compras))

productos = []


for i in range(len(compras)):
# Out:
# [{'cliente': '80849599',
#   'productos': [{'cantidad': 3,
#                  'nombre': 'Chocolatinas Cohete',
#                  'precio unitario': 300},
#                 {'cantidad': 1, 'nombre': 'Mora', 'precio unitario': 1000},
#                 {'cantidad': 5,
#                  'nombre': 'Pan de Maiz',
#                  'precio unitario': 300}]},
#  {'cliente': '1022734737',
#   'productos': [{'cantidad': 2,
#                  'nombre': 'Televisor',
#                  'precio unitario': 1500000},
#                 {'cantidad': 1,
#                  'nombre': 'Teatro en Casa',
#                  'precio unitario': 450000}]},
#  {'cliente': '827363',
#   'productos': [{'cantidad': 5,
#                  'nombre': 'Camiseta',
#                  'precio unitario': 300000},
#                 {'cantidad': 1,
#                  'nombre': 'Teatro en Casa',
#                  'precio unitario': 450000}]},
#  {'cliente': '827363',
#   'productos': [{'cantidad': 1,
# ...

# %%
import json 
import requests
from pprint import pprint

url = input("Digite el link: ")

response = requests.get(url)
datos = json.loads(response.text)

pprint(datos)
